# %%
from collections import defaultdict
from tqdm import tqdm

import numpy as np
import math
import statistics as stat
import random

from matchings import cross_bin_matching, same_bin_matching, immediate_neighbor_matching, max_weight_matching
from scipy.stats import norm

import matplotlib.pyplot as plt
from matplotlib import ticker, patches

lblue  = (40/255,103/255,178/255)
sgreen = (46/255,139/255,87/255)
cred   = (177/255,4/255,14/255)


plt.rcParams.update({
    'lines.linewidth' : 1.,
    'lines.markersize' : 5,
    'font.size': 10,
    "text.usetex": True,
    'font.family': 'serif', 
    'font.serif': ['Computer Modern'],
    'text.latex.preamble' : r'\usepackage{amsmath,amsfonts}',
    'axes.linewidth' : .75})

# %%
def SCINT_test(X, Y, M, nperm=500):
    Del_X = np.array([X[i]-X[j] for (i,j) in M])
    Del_Y = np.array([Y[i]-Y[j] for (i,j) in M])
    
    D_S = np.einsum('ij, j, j -> i', 
                    (np.random.rand(nperm, len(M)) < .5), 
                    Del_X, 
                    Del_Y)
    
    return (1+np.sum(D_S <= 0))/(1+nperm)

# %%
n = 500
eta = 1/n**.5
K = int(1/eta)
print(K, eta)
len(np.arange(0, 1+eta, eta)), K
#np.array_split(np.arange(n), 5)
# Out:
# 22 0.044721359549995794
# (24, 22)

# %% [markdown]
# # Type I error analysis

# %%
# %%time
nrep = 10000#100000

gamma_seq = 10**np.linspace(-1, 1, 7) #[.1, 1, 10]
n = 500
#eta = 1/(n**0.75)
eta = 1/n**.5
# K = int(1/eta)


def effect_on_validity():
    pvalues = defaultdict(lambda : defaultdict(lambda : np.zeros(nrep)))
        
    for l in tqdm(range(nrep)):
#         if l%10000==0: print(l/10000)
        Z = np.random.normal(0,1,n)
        Y = np.random.normal(0,1,n)
        # eta = 1/(n**0.75)
        K = 7*np.floor(n**0.5)

        matchings = {}
        matchings['nbhd'] = immediate_neighbor_matching(Y, Z)
        matchings['cb']   = cross_bin_matching(Y, Z, K)

        for gamma in gamma_seq:
            for setting in range(2):
                if setting==0:
                    mu=gamma*Z
                elif setting==1:
                    mu=norm.cdf(gamma*Z)
                X = mu + np.random.normal(0,1,n)
                for label, M in matchings.items():
                    pvalues[(setting, label)][gamma][l] = SCINT_test(X,Y,M)
    return(pvalues)

results = effect_on_validity()
# Out:
# 100%|█████████████████████████████████████| 10000/10000 [01:52<00:00, 89.04it/s]
# CPU times: user 1min 51s, sys: 1.08 s, total: 1min 52s
# Wall time: 1min 52s

# %%
titles
# Out:
# ['$\\mathbb E[X|Z]=$ $\\gamma Z$', '$\\mathbb E[X|Z]=$ $\\Phi(\\gamma Z)$']

# %%
# nrep = 1000000
import matplotlib.gridspec as gridspec

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3.2), sharex=True, sharey=True)  # Adjusted to 4 columns for side-by-side plots

alphas = [.01, .1]
col_titles = [r'$\alpha=$ {}'.format(col) for col in ['$0.01$', '$0.1$']]
titles = [r'$X = ' + setting_name + ' + \\zeta$ ' for setting_name in ['\\gamma Z', '\\Phi(\\gamma Z)']]

methods = [('nbhd', "Neighbour", sgreen, '^'), 
           ('cb', "Cross-bin", lblue, 'o')]

# Using GridSpec to control spacing
gs = gridspec.GridSpec(1, 4, width_ratios=[1, 1, 0.1, 1], wspace=0.8)  # Control widths and spacing


for setting in range(2):
    start_col = setting * 2  # Starting column index for each setting

    for col in range(2):
        axes[start_col + col].set_title(col_titles[col])

        alpha = alphas[col]
        for nm, name, color, shape in methods:
            axes[start_col + col].plot(gamma_seq, [np.mean(results[(setting, nm)][gamma] < alpha) for gamma in gamma_seq], 
                                       marker=shape, linestyle='solid', c=color, label=name)
            axes[start_col + col].axhline(y=alpha, c=(0,0,0), linestyle='--')

# Formatting and labels
axes[0].set_xscale('log')
axes[0].set_xticks([.1, 1, 10], [.1, 1, 10], rotation='vertical')
axes[0].get_xaxis().set_major_formatter(ticker.ScalarFormatter())
axes[0].get_xaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(float(x), ',')))

for i in range(4):
    labels = axes[i].get_xticklabels()
    plt.setp(labels, rotation=30, horizontalalignment='right')

# sub-column titles
fig.text(0.28, 0.99, 'Setting 1: ' + titles[0], ha='center', fontsize=12, fontweight='bold')
fig.text(0.76, 0.99, 'Setting 2: ' + titles[1], ha='center', fontsize=12, fontweight='bold')

# Adjusting the layout: Tighten the gap between columns 1 and 2 and increase gap between columns 2 and 3
plt.subplots_adjust(left=0.08, right=0.92, top=0.92, bottom=0.15, wspace=1)  # Larger wspace for more separation between columns 2 and 3


fig.supxlabel('Strength of Stochastic Monotonicity $\\gamma$', y=.03)
axes[0].set_ylabel('Prob. of Rejection')
axes[3].legend(loc='lower left')

plt.tight_layout()
fig.savefig('figures/validity_curve_log_tall_sidebyside.pdf', bbox_inches='tight')
plt.show()

# %%
# nrep = 1000000
for setting in range(2):
    tart_col = setting * 
    fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(10.3, 3.2), # 4.875
                             sharex=True, sharey=True)

    alphas = [.01, .1]
    col_titles = [r'$\alpha=$ {}'.format(col) for col in ['$0.01$','$0.1$']]
    #titles = [r'$\mathbb E[X|Z]=$ {}'.format(setting_name) for setting_name in ['$\\gamma Z$', '$\Phi(\\gamma Z)$']]
    titles = [r'$X = ' + setting_name + ' + \\zeta$ ' for setting_name in ['\\gamma Z', '\Phi(\\gamma Z)']]

    methods = [('nbhd', "Neighbour", sgreen, '^'), 
               ('cb', "Cross-bin", lblue, 'o'), 
    #            ('sb', "Same bin", cred), 
              ]
    axes[0].set_ylim([0, .105])
    for col in range(2):
        axes[col].set_title(col_titles[col])

        alpha = alphas[col]
#         for row, title in enumerate(row_titles):
        for nm, name, color, shape in methods:
#             print(len(results[(setting,nm)][.1] < alpha))
            axes[col].plot(gamma_seq, [np.mean(results[(setting,nm)][gamma] < alpha) for gamma in gamma_seq], marker=shape, 
                               linestyle='solid', c=color, label=name)
        axes[col].axhline(y=alpha,c=(0,0,0),linestyle='--')


    lines = [] 
    labels = [] 
    Line, Label = axes[0].get_legend_handles_labels() 
    lines.extend(Line) 
    labels.extend(Label) 

    axes[0].set_xscale('log')#, base=2)
    axes[0].set_xticks([.1, 1, 10], [.1, 1, 10], rotation='vertical')
    axes[0].get_xaxis().set_major_formatter(ticker.ScalarFormatter())
    axes[0].get_xaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(float(x), ',')))
    for i in range(2):
        labels = axes[i].get_xticklabels()
        plt.setp(labels, rotation=30, horizontalalignment='right')


    fig.suptitle('Setting %d: ' %(setting+1) + titles[setting], y=.97)
    fig.supxlabel('Strength of stochastic monotonicity $\\gamma$', y=.03)
    # fig.supylabel('Type I error')
    axes[0].set_ylabel('Prob. of rejection')
    # fig.legend(lines, labels, loc='right')
    axes[1].legend(loc='lower left')
    plt.tight_layout()
    #fig.savefig('figures/validity_curve_log_tall-nrep=%d-setting=%d.pdf' % (nrep, setting ), bbox_inches='tight')
    plt.show()

# %%
# nrep = 1000000
for setting in range(2):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(6.5, 3.2), # 4.875
                             sharex=True, sharey=True)

    alphas = [.01, .05, .1]
    col_titles = [r'$\alpha=$ {}'.format(col) for col in ['$0.01$','$0.05$','$0.1$']]
    #titles = [r'$\mathbb E[X|Z]=$ {}'.format(setting_name) for setting_name in ['$\\gamma Z$', '$\Phi(\\gamma Z)$']]
    titles = [r'$X = ' + setting_name + ' + \\zeta$ ' for setting_name in ['\\gamma Z', '\Phi(\\gamma Z)']]

    methods = [('nbhd', "Neighbour", sgreen, '^'), 
               ('cb', "Cross-bin", lblue, 'o'), 
    #            ('sb', "Same bin", cred), 
              ]
    axes[0].set_ylim([0, .105])
    for col in range(3):
        axes[col].set_title(col_titles[col])

        alpha = alphas[col]
#         for row, title in enumerate(row_titles):
        for nm, name, color, shape in methods:
#             print(len(results[(setting,nm)][.1] < alpha))
            axes[col].plot(gamma_seq, [np.mean(results[(setting,nm)][gamma] < alpha) for gamma in gamma_seq], marker=shape, 
                               linestyle='solid', c=color, label=name)
        axes[col].axhline(y=alpha,c=(0,0,0),linestyle='--')


    lines = [] 
    labels = [] 
    Line, Label = axes[0].get_legend_handles_labels() 
    lines.extend(Line) 
    labels.extend(Label) 

    axes[0].set_xscale('log')#, base=2)
    axes[0].set_xticks([.1, 1, 10], [.1, 1, 10], rotation='vertical')
    axes[0].get_xaxis().set_major_formatter(ticker.ScalarFormatter())
    axes[0].get_xaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(float(x), ',')))
    for i in range(3):
        labels = axes[i].get_xticklabels()
        plt.setp(labels, rotation=30, horizontalalignment='right')


    fig.suptitle('Setting %d: ' %(setting+1) + titles[setting], y=.97)
    fig.supxlabel('Strength of stochastic monotonicity $\\gamma$', y=.03)
    # fig.supylabel('Type I error')
    axes[0].set_ylabel('Prob. of rejection')
    # fig.legend(lines, labels, loc='right')
    axes[2].legend(loc='lower left')
    plt.tight_layout()
    #fig.savefig('figures/validity_curve_log_tall-nrep=%d-setting=%d.pdf' % (nrep, setting ), bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Power analysis

# %%
def sim_YZ(n, setting):
    if setting == 1:
        rho = 0
    elif setting == 2:
        rho = .5
    elif setting == 3:
        rho = -.5

    cov = (1-rho)*np.eye(2) + rho*np.ones((2,2))
    Y, Z = np.random.multivariate_normal([0,0], cov, size=n).T
        
    return Y, Z

# %%
# %%time
nrep= 1000#10000
alpha=0.1 

nseq=np.array([500, 2500, 5000, 7500, 10000, 20000, 40000, 80000])

def power_analysis_sim(setting):
    pvalues = defaultdict(lambda : defaultdict(lambda : np.zeros(nrep)))
    power   = defaultdict(lambda : defaultdict(float))
    for n in nseq:
        eta = 1/(n**0.5) #1/(n**0.75)

        
        for l in tqdm(range(nrep)):
            Y,Z = sim_YZ(n, setting)

            matchings = {}
            matchings['nbhd'] = immediate_neighbor_matching(Y, Z)
            #matchings['sb']   = same_bin_matching(Y, Z, eta)
            K = 7*np.floor(n**0.5)
            matchings['cb']   = cross_bin_matching(Y, Z, K)
            
            beta = 1/(n**(1/3))
            for gamma in [1,5]: 
                X = gamma*Z + beta*Y + np.random.normal(0,1,n)
                for label, M in matchings.items():
                    pvalues[(gamma, label)][n][l] = SCINT_test(X,Y,M)
        for k in pvalues:
            power[k][n] = np.mean(pvalues[k][n] < alpha)
    return(pvalues, power)

power_results = []
_, power1 = power_analysis_sim(1)
power_results.append(power1)

_, power2 = power_analysis_sim(2)
power_results.append(power2)

_, power3 = power_analysis_sim(3)
power_results.append(power3)
# Out:
# 100%|██████████████████████████████████████| 1000/1000 [00:02<00:00, 381.14it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:12<00:00, 77.00it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:27<00:00, 36.42it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:40<00:00, 24.41it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:55<00:00, 18.10it/s]
# 100%|███████████████████████████████████████| 1000/1000 [01:53<00:00,  8.82it/s]
# 100%|███████████████████████████████████████| 1000/1000 [03:48<00:00,  4.38it/s]
# 100%|███████████████████████████████████████| 1000/1000 [09:35<00:00,  1.74it/s]
# 100%|██████████████████████████████████████| 1000/1000 [00:02<00:00, 379.77it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:12<00:00, 77.00it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:27<00:00, 36.40it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:41<00:00, 24.21it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:55<00:00, 17.94it/s]
# 100%|███████████████████████████████████████| 1000/1000 [01:53<00:00,  8.82it/s]
# 100%|███████████████████████████████████████| 1000/1000 [03:47<00:00,  4.40it/s]
# 100%|███████████████████████████████████████| 1000/1000 [09:29<00:00,  1.76it/s]
# 100%|██████████████████████████████████████| 1000/1000 [00:02<00:00, 410.68it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:12<00:00, 77.91it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:27<00:00, 36.76it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:40<00:00, 24.52it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:55<00:00, 18.05it/s]
# 100%|███████████████████████████████████████| 1000/1000 [01:53<00:00,  8.85it/s]
# 100%|███████████████████████████████████████| 1000/1000 [03:46<00:00,  4.41it/s]
# 100%|███████████████████████████████████████| 1000/1000 [09:34<00:00,  1.74it/s]
# CPU times: user 1h 9min 29s, sys: 1h 15min 32s, total: 2h 25min 1s
# Wall time: 52min 39s

# %%
power_results
# Out:
# [defaultdict(<function __main__.power_analysis_sim.<locals>.<lambda>()>,
#              {(1,
#                'nbhd'): defaultdict(float,
#                           {500: 0.507,
#                            1000: 0.587,
#                            5000: 0.755,
#                            10000: 0.838}),
#               (1,
#                'cb'): defaultdict(float,
#                           {500: 0.677,
#                            1000: 0.788,
#                            5000: 0.954,
#                            10000: 0.983}),
#               (5,
#                'nbhd'): defaultdict(float,
#                           {500: 0.356,
#                            1000: 0.492,
#                            5000: 0.733,
#                            10000: 0.818}),
#               (5,
#                'cb'): defaultdict(float,
#                           {500: 0.002,
#                            1000: 0.003,
#                            5000: 0.005,
#                            10000: 0.014}),
#               (10, 'nbhd'): defaultdict(float, {})}),
#  defaultdict(<function __main__.power_analysis_sim.<locals>.<lambda>()>,
#              {(1,
#                'nbhd'): defaultdict(float,
#                           {500: 0.462, 1000: 0.503, 5000: 0.67, 10000: 0.757}),
#               (1,
#                'cb'): defaultdict(float,
#                           {500: 0.543,
#                            1000: 0.663,
#                            5000: 0.879,
#                            10000: 0.946}),
#               (5,
#                'nbhd'): defaultdict(float,
#                           {500: 0.31, 1000: 0.413, 5000: 0.639, 10000: 0.716}),
#               (5,
#                'cb'): defaultdict(float,
#                           {500: 0.0, 1000: 0.001, 5000: 0.001, 10000: 0.01})}),
#  defaultdict(<function __main__.power_analysis_sim.<locals>.<lambda>()>,
#              {(1,
#                'nbhd'): defaultdict(float,
#                           {500: 0.441, 1000: 0.528, 5000: 0.68, 10000: 0.783}),
#               (1,
#                'cb'): defaultdict(float,
#                           {500: 0.534,
#                            1000: 0.654,
#                            5000: 0.875,
#                            10000: 0.952}),
#               (5,
#                'nbhd'): defaultdict(float,
#                           {500: 0.284, 1000: 0.391, 5000: 0.644, 10000: 0.71}),
#               (5,
#                'cb'): defaultdict(float,
#                           {500: 0.0, 1000: 0.0, 5000: 0.0, 10000: 0.001})})]

# %%
titles = ['$X = \\beta_n Y + Z + \\zeta$', '$X = \\beta_n Y + 10 Z + \\zeta$']
for ind, gamma in enumerate([1,5]):
    from matplotlib.transforms import offset_copy

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(7, 2.2), 
                             sharex=True, sharey='row')

    col_titles = [r'$\rho_{Y,Z}' + col_name for col_name in ['=0$','>0$','<0$']]

    methods = [('nbhd', "Neighbour", sgreen, '^'), 
               ('cb', "Cross-bin", lblue, 'o'), 
              ]

    for col in range(3):
        axes[col].set_title(col_titles[col])
        for nm, name, color, shape in methods:
            axes[col].semilogx(nseq, power_results[col][(gamma, nm)].values(), marker=shape, 
                               linestyle='solid', c=color, label=name)

    axes[0].set_ylabel('Prob. of Rejection')

    lines = [] 
    labels = [] 
    Line, Label = axes[0].get_legend_handles_labels() 
    lines.extend(Line) 
    labels.extend(Label) 

    # axes[0,0].set_xscale('log')#, base=2)
    # axes[0].set_xticks(nseq, nseq, rotation='vertical')
    # axes[0].get_xaxis().set_major_formatter(ticker.ScalarFormatter())
    # axes[0].get_xaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

    # Select fewer x-ticks to reduce overlap
    selected_xticks = sorted(set([nseq[0], nseq[-1]] + list(nseq[::2])))   
    for ax in axes:
        ax.set_xticks(selected_xticks)  
        ax.set_xticklabels([f'{int(x):,}' for x in selected_xticks], rotation=40, ha='right',fontsize=8) 


    # for i in range(3):
        # labels = axes[i].get_xticklabels()
        # plt.setp(labels, rotation=60, horizontalalignment='right')
    # axes[0,0].set_xticks(nseq, nseq, rotation=)
    # axes[0,0]..tick_params(axis='x', labelrotation=90)

    fig.supxlabel('Sample size $n$', y=-.18)
    fig.suptitle('Setting %d: ' % (ind+1)+ titles[ind], y=1.14)
    
    axes[0].set_ylim([-.03,1.03])

    axes[2].legend(loc='lower right') 
    fig.savefig('figures/power-nrep=%d-gamma=%d.pdf' % (nrep, gamma), bbox_inches='tight')
    plt.show()

# %%
power_results[0][1].values()
# Out:
# dict_values([0.935, 0.971, 0.999, 1.0])

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
from scipy.linalg import sqrtm

# %%
dd = 1
pp = 2*dd
S = np.eye(pp)
rho = .54
for j in range(dd):
    S[j,j+dd]=rho
    S[j+dd,j]=rho
sqrtm(S), np.array([[np.sqrt((1+np.sqrt(1-rho**2))/2), np.sqrt((1-np.sqrt(1-rho**2))/2)]])
# Out:
# (array([[0.95960018, 0.28136718],
#         [0.28136718, 0.95960018]]),
#  array([[0.95960018, 0.28136718]]))

# %% [markdown]
# \begin{align*}
# K &= \begin{bmatrix}
# a & b \\
# b & a
# \end{bmatrix} \\
# K^2 &= \begin{bmatrix}
# a^2+b^2 & 2ab \\
# 2ab & a^2+b^2
# \end{bmatrix}
# = \begin{bmatrix}
# 1 & \rho \\
# \rho & 1
# \end{bmatrix}
# \end{align*}
#
# $0=4A^2-4A+rho^2$
#
# $A = \frac{1\pm \sqrt{1-\rho^2}}{2}$
#
# $b = \rho/(2a)$

# %%
# Out:
# 0.5310885545960922
